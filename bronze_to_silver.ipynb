# %%
import pyspark
from pyspark.sql import functions as F
from pyspark.sql.types import *

# %%
tables = spark.sql("show tables in etl_projects.bronze")
display(tables)

# %%
tables_name = [
    row.tableName for row in tables.collect()
]
print(tables_name)
